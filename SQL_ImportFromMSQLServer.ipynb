# %%
#Load from Microsoft SQL

# %%
import pandas as pd
 
from sqlalchemy import create_engine

# %%
import pyodbc
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=PC-UTILISATEUR\MSSQLSERVER01;'
                      'Database=KAYAK;'
                      'Trusted_Connection=yes;')

cursor = conn.cursor()
cursor.execute('SELECT * FROM CustomerAddress')

for row in cursor:
    print(row)
# Out:
# (29485, 'M s', 'Catherine R. Abel', 'Professional Sales and Service', 'linda3', None, '7475550171', 1086, '57251 Serene Blvd |Van Nuys |California |91411', 'United States')
# (29486, 'M s', 'Kim  Abercrombie', 'Riders Company', 'jillian0', None, '3345550137', 621, 'Tanger Factory |Branch |Minnesota |55056', 'United States')
# (29489, 'M s', 'Frances B. Adams', 'Area Bike Accessories', 'shu0', None, '9915550183', 1069, '6900 Sisk Road |Modesto |California |95354', 'United States')
# (29490, 'M s', 'Margaret J. Smith', 'Bicycle Accessories and Kits', 'david8', None, '9595550151', 887, 'Lewiston Mall |Lewiston |Idaho |83501', 'United States')
# (29492, 'M r', 'Jay  Adams', 'Valley Bicycle Specialists', 'jillian0', None, '1585550142', 618, 'Blue Ridge Mall |Kansas City |Missouri |64106', 'United States')
# (29494, 'M r', 'Samuel N. Agcaoili', 'Vinyl and Plastic Goods Corporation', 'josé1', None, '5545550110', 537, 'No. 25800-130 King Street West |Toronto |Ontario |M4B 1V5', 'Canada')
# ...

# %%
cursor

# %%
######################""Inserting data from Python to SQL server

# %%
import pyodbc
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=PC-UTILISATEUR\MSSQLSERVER01;'
                      'Database=PythonDB2;'
                      'Trusted_Connection=yes;')

cursor = conn.cursor()
cursor.execute('''CREATE TABLE PythonData(Id int, Name nvarchar(50),DOB date)''')
conn.close()

# %%
import pyodbc
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=PC-UTILISATEUR\MSSQLSERVER01;'
                      'Database=PythonDB2;'
                      'Trusted_Connection=yes;')

cursor = conn.cursor()
cursor.execute(' insert into PythonTable(id , name ,LastName , DOB) values (1,''Michael'','' Kidane'',''1987-12-01')
conn.close()

# %%
a=5
a

# %%
print('HI')

# %%
print(' insert into PythonTable(id , name ,LastName , DOB) values (1,''Michael'','' Kidane'',''1987-12-01')

# %%
print('HI')
